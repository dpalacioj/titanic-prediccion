# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
DATA_DIR = Path.cwd().resolve().parent / "datos"

datos_titanic = pd.read_parquet(DATA_DIR / "02_datos_con_tipo_de_dato_ajustado_titanic.parquet")

# %% [markdown]
# # Selección de columnas y estructura del dataframe

# %%
datos_titanic.columns
# Out:
# Index(['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked'],
#       dtype='object')

# %%
datos_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   bool
#  2   sex       1309 non-null   category
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   fare      1308 non-null   float64
#  7   embarked  1307 non-null   category
# dtypes: bool(1), category(2), float64(2), int64(3)
# memory usage: 55.3 KB

# %%
from pycaret.classification import setup, compare_models

# %%
target_col = "survived"

# %%
clf_setup = setup(
    data = datos_titanic,
    target = target_col,
    session_id =  42,

    # Parámetros para controlar el preprocesamiento:
    numeric_features = ['age', 'fare', 'sibsp', 'parch'],
    categorical_features = ['sex', 'embarked'],
    ordinal_features = {'pclass': [1,2,3]},

    # Estrategias de imputacion
    numeric_imputation = 'mean',
    categorical_imputation = 'mode',
)
# Out:
# <style type="text/css">
# #T_378a9_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_378a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_378a9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_378a9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_378a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_378a9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_378a9_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_378a9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_378a9_row1_col1" class="data row1 col1" >survived</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_378a9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_378a9_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_378a9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_378a9_row3_col1" class="data row3 col1" >(1309, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_378a9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_378a9_row4_col1" class="data row4 col1" >(1309, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_378a9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_378a9_row5_col1" class="data row5 col1" >(916, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_378a9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_378a9_row6_col1" class="data row6 col1" >(393, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_378a9_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_378a9_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_378a9_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_378a9_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_378a9_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_378a9_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_378a9_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_378a9_row10_col1" class="data row10 col1" >20.3%</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_378a9_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_378a9_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_378a9_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_378a9_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_378a9_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_378a9_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_378a9_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_378a9_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_378a9_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_378a9_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_378a9_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_378a9_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_378a9_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_378a9_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_378a9_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_378a9_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_378a9_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_378a9_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_378a9_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_378a9_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_378a9_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_378a9_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_378a9_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_378a9_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_378a9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_378a9_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_378a9_row23_col1" class="data row23 col1" >137d</td>
#     </tr>
#   </tbody>
# </table>

# %%
datos_titanic['survived'].value_counts()
# Out:
# False    809
# True     500
# Name: survived, dtype: int64

# %%
best_model = compare_models(
    include=['lr', 'rf', 'gbc', 'lightgbm'],
    sort='Accuracy',
    n_select=4
)
# Out:
# <style type="text/css">
# #T_53dde th {
#   text-align: left;
# }
# #T_53dde_row0_col0, #T_53dde_row0_col2, #T_53dde_row0_col4, #T_53dde_row1_col0, #T_53dde_row1_col1, #T_53dde_row1_col2, #T_53dde_row1_col3, #T_53dde_row1_col4, #T_53dde_row1_col5, #T_53dde_row1_col6, #T_53dde_row1_col7, #T_53dde_row2_col0, #T_53dde_row2_col1, #T_53dde_row2_col3, #T_53dde_row2_col5, #T_53dde_row2_col6, #T_53dde_row2_col7, #T_53dde_row3_col0, #T_53dde_row3_col1, #T_53dde_row3_col2, #T_53dde_row3_col3, #T_53dde_row3_col4, #T_53dde_row3_col5, #T_53dde_row3_col6, #T_53dde_row3_col7 {
#   text-align: left;
# }
# #T_53dde_row0_col1, #T_53dde_row0_col3, #T_53dde_row0_col5, #T_53dde_row0_col6, #T_53dde_row0_col7, #T_53dde_row2_col2, #T_53dde_row2_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_53dde_row0_col8, #T_53dde_row1_col8, #T_53dde_row3_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_53dde_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_53dde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53dde_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_53dde_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_53dde_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_53dde_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_53dde_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_53dde_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_53dde_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_53dde_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_53dde_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53dde_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_53dde_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_53dde_row0_col1" class="data row0 col1" >0.7957</td>
#       <td id="T_53dde_row0_col2" class="data row0 col2" >0.8295</td>
#       <td id="T_53dde_row0_col3" class="data row0 col3" >0.7143</td>
#       <td id="T_53dde_row0_col4" class="data row0 col4" >0.7437</td>
#       <td id="T_53dde_row0_col5" class="data row0 col5" >0.7267</td>
#       <td id="T_53dde_row0_col6" class="data row0 col6" >0.5641</td>
#       <td id="T_53dde_row0_col7" class="data row0 col7" >0.5663</td>
#       <td id="T_53dde_row0_col8" class="data row0 col8" >0.4960</td>
#     </tr>
#     <tr>
#       <th id="T_53dde_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_53dde_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_53dde_row1_col1" class="data row1 col1" >0.7935</td>
#       <td id="T_53dde_row1_col2" class="data row1 col2" >0.8327</td>
#       <td id="T_53dde_row1_col3" class="data row1 col3" >0.7057</td>
#       <td id="T_53dde_row1_col4" class="data row1 col4" >0.7447</td>
#       <td id="T_53dde_row1_col5" class="data row1 col5" >0.7221</td>
#       <td id="T_53dde_row1_col6" class="data row1 col6" >0.5584</td>
#       <td id="T_53dde_row1_col7" class="data row1 col7" >0.5613</td>
#       <td id="T_53dde_row1_col8" class="data row1 col8" >0.1540</td>
#     </tr>
#     <tr>
#       <th id="T_53dde_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_53dde_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_53dde_row2_col1" class="data row2 col1" >0.7924</td>
#       <td id="T_53dde_row2_col2" class="data row2 col2" >0.8467</td>
#       <td id="T_53dde_row2_col3" class="data row2 col3" >0.6571</td>
#       <td id="T_53dde_row2_col4" class="data row2 col4" >0.7645</td>
#       <td id="T_53dde_row2_col5" class="data row2 col5" >0.7057</td>
#       <td id="T_53dde_row2_col6" class="data row2 col6" >0.5473</td>
#       <td id="T_53dde_row2_col7" class="data row2 col7" >0.5517</td>
#       <td id="T_53dde_row2_col8" class="data row2 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_53dde_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_53dde_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_53dde_row3_col1" class="data row3 col1" >0.7739</td>
#       <td id="T_53dde_row3_col2" class="data row3 col2" >0.8243</td>
#       <td id="T_53dde_row3_col3" class="data row3 col3" >0.6686</td>
#       <td id="T_53dde_row3_col4" class="data row3 col4" >0.7209</td>
#       <td id="T_53dde_row3_col5" class="data row3 col5" >0.6906</td>
#       <td id="T_53dde_row3_col6" class="data row3 col6" >0.5137</td>
#       <td id="T_53dde_row3_col7" class="data row3 col7" >0.5171</td>
#       <td id="T_53dde_row3_col8" class="data row3 col8" >0.8420</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import create_model, tune_model, predict_model

print("Creando el modelo lightgbm...")
gbc_model = create_model('lightgbm')

print("\n")
print("------")
print("\n")

print("Realizando fine-tuning del modelo....")
gbc_tuned = tune_model(gbc_model)

print("\n")
print("------")
print("\n")

print("Resumen del modelo")
print(gbc_tuned)

print("\n")
print("------")
print("\n")

print("Predicciones en el conjunto/set de test")
predicciones_internas = predict_model(gbc_tuned)

print("\n")
print("------")
print("\n")


print(predicciones_internas.head())
# Out:
# Creando el modelo lightgbm...
# <style type="text/css">
# #T_8282d_row10_col0, #T_8282d_row10_col1, #T_8282d_row10_col2, #T_8282d_row10_col3, #T_8282d_row10_col4, #T_8282d_row10_col5, #T_8282d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8282d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8282d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8282d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8282d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8282d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8282d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8282d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8282d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8282d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8282d_row0_col0" class="data row0 col0" >0.8043</td>
#       <td id="T_8282d_row0_col1" class="data row0 col1" >0.8155</td>
#       <td id="T_8282d_row0_col2" class="data row0 col2" >0.7143</td>
#       <td id="T_8282d_row0_col3" class="data row0 col3" >0.7576</td>
#       <td id="T_8282d_row0_col4" class="data row0 col4" >0.7353</td>
#       <td id="T_8282d_row0_col5" class="data row0 col5" >0.5803</td>
#       <td id="T_8282d_row0_col6" class="data row0 col6" >0.5810</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8282d_row1_col0" class="data row1 col0" >0.7609</td>
#       <td id="T_8282d_row1_col1" class="data row1 col1" >0.8591</td>
#       <td id="T_8282d_row1_col2" class="data row1 col2" >0.7714</td>
#       <td id="T_8282d_row1_col3" class="data row1 col3" >0.6585</td>
#       <td id="T_8282d_row1_col4" class="data row1 col4" >0.7105</td>
#       <td id="T_8282d_row1_col5" class="data row1 col5" >0.5090</td>
#       <td id="T_8282d_row1_col6" class="data row1 col6" >0.5136</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8282d_row2_col0" class="data row2 col0" >0.7935</td>
#       <td id="T_8282d_row2_col1" class="data row2 col1" >0.8667</td>
#       <td id="T_8282d_row2_col2" class="data row2 col2" >0.6571</td>
#       <td id="T_8282d_row2_col3" class="data row2 col3" >0.7667</td>
#       <td id="T_8282d_row2_col4" class="data row2 col4" >0.7077</td>
#       <td id="T_8282d_row2_col5" class="data row2 col5" >0.5495</td>
#       <td id="T_8282d_row2_col6" class="data row2 col6" >0.5534</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8282d_row3_col0" class="data row3 col0" >0.8696</td>
#       <td id="T_8282d_row3_col1" class="data row3 col1" >0.9118</td>
#       <td id="T_8282d_row3_col2" class="data row3 col2" >0.8286</td>
#       <td id="T_8282d_row3_col3" class="data row3 col3" >0.8286</td>
#       <td id="T_8282d_row3_col4" class="data row3 col4" >0.8286</td>
#       <td id="T_8282d_row3_col5" class="data row3 col5" >0.7233</td>
#       <td id="T_8282d_row3_col6" class="data row3 col6" >0.7233</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8282d_row4_col0" class="data row4 col0" >0.8261</td>
#       <td id="T_8282d_row4_col1" class="data row4 col1" >0.8774</td>
#       <td id="T_8282d_row4_col2" class="data row4 col2" >0.8286</td>
#       <td id="T_8282d_row4_col3" class="data row4 col3" >0.7436</td>
#       <td id="T_8282d_row4_col4" class="data row4 col4" >0.7838</td>
#       <td id="T_8282d_row4_col5" class="data row4 col5" >0.6390</td>
#       <td id="T_8282d_row4_col6" class="data row4 col6" >0.6417</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8282d_row5_col0" class="data row5 col0" >0.8261</td>
#       <td id="T_8282d_row5_col1" class="data row5 col1" >0.8837</td>
#       <td id="T_8282d_row5_col2" class="data row5 col2" >0.7143</td>
#       <td id="T_8282d_row5_col3" class="data row5 col3" >0.8065</td>
#       <td id="T_8282d_row5_col4" class="data row5 col4" >0.7576</td>
#       <td id="T_8282d_row5_col5" class="data row5 col5" >0.6228</td>
#       <td id="T_8282d_row5_col6" class="data row5 col6" >0.6255</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8282d_row6_col0" class="data row6 col0" >0.8132</td>
#       <td id="T_8282d_row6_col1" class="data row6 col1" >0.8500</td>
#       <td id="T_8282d_row6_col2" class="data row6 col2" >0.7429</td>
#       <td id="T_8282d_row6_col3" class="data row6 col3" >0.7647</td>
#       <td id="T_8282d_row6_col4" class="data row6 col4" >0.7536</td>
#       <td id="T_8282d_row6_col5" class="data row6 col5" >0.6032</td>
#       <td id="T_8282d_row6_col6" class="data row6 col6" >0.6034</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8282d_row7_col0" class="data row7 col0" >0.7363</td>
#       <td id="T_8282d_row7_col1" class="data row7 col1" >0.7505</td>
#       <td id="T_8282d_row7_col2" class="data row7 col2" >0.5714</td>
#       <td id="T_8282d_row7_col3" class="data row7 col3" >0.6897</td>
#       <td id="T_8282d_row7_col4" class="data row7 col4" >0.6250</td>
#       <td id="T_8282d_row7_col5" class="data row7 col5" >0.4244</td>
#       <td id="T_8282d_row7_col6" class="data row7 col6" >0.4288</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8282d_row8_col0" class="data row8 col0" >0.7253</td>
#       <td id="T_8282d_row8_col1" class="data row8 col1" >0.7439</td>
#       <td id="T_8282d_row8_col2" class="data row8 col2" >0.6286</td>
#       <td id="T_8282d_row8_col3" class="data row8 col3" >0.6471</td>
#       <td id="T_8282d_row8_col4" class="data row8 col4" >0.6377</td>
#       <td id="T_8282d_row8_col5" class="data row8 col5" >0.4165</td>
#       <td id="T_8282d_row8_col6" class="data row8 col6" >0.4166</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8282d_row9_col0" class="data row9 col0" >0.8022</td>
#       <td id="T_8282d_row9_col1" class="data row9 col1" >0.7360</td>
#       <td id="T_8282d_row9_col2" class="data row9 col2" >0.6857</td>
#       <td id="T_8282d_row9_col3" class="data row9 col3" >0.7742</td>
#       <td id="T_8282d_row9_col4" class="data row9 col4" >0.7273</td>
#       <td id="T_8282d_row9_col5" class="data row9 col5" >0.5730</td>
#       <td id="T_8282d_row9_col6" class="data row9 col6" >0.5756</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8282d_row10_col0" class="data row10 col0" >0.7957</td>
#       <td id="T_8282d_row10_col1" class="data row10 col1" >0.8295</td>
#       <td id="T_8282d_row10_col2" class="data row10 col2" >0.7143</td>
#       <td id="T_8282d_row10_col3" class="data row10 col3" >0.7437</td>
#       <td id="T_8282d_row10_col4" class="data row10 col4" >0.7267</td>
#       <td id="T_8282d_row10_col5" class="data row10 col5" >0.5641</td>
#       <td id="T_8282d_row10_col6" class="data row10 col6" >0.5663</td>
#     </tr>
#     <tr>
#       <th id="T_8282d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8282d_row11_col0" class="data row11 col0" >0.0418</td>
#       <td id="T_8282d_row11_col1" class="data row11 col1" >0.0610</td>
#       <td id="T_8282d_row11_col2" class="data row11 col2" >0.0788</td>
#       <td id="T_8282d_row11_col3" class="data row11 col3" >0.0572</td>
#       <td id="T_8282d_row11_col4
# ------
#
#
# Realizando fine-tuning del modelo....
# <style type="text/css">
# #T_96ebd_row10_col0, #T_96ebd_row10_col1, #T_96ebd_row10_col2, #T_96ebd_row10_col3, #T_96ebd_row10_col4, #T_96ebd_row10_col5, #T_96ebd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_96ebd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96ebd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_96ebd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_96ebd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_96ebd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_96ebd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_96ebd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_96ebd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96ebd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96ebd_row0_col0" class="data row0 col0" >0.7826</td>
#       <td id="T_96ebd_row0_col1" class="data row0 col1" >0.8188</td>
#       <td id="T_96ebd_row0_col2" class="data row0 col2" >0.6286</td>
#       <td id="T_96ebd_row0_col3" class="data row0 col3" >0.7586</td>
#       <td id="T_96ebd_row0_col4" class="data row0 col4" >0.6875</td>
#       <td id="T_96ebd_row0_col5" class="data row0 col5" >0.5231</td>
#       <td id="T_96ebd_row0_col6" class="data row0 col6" >0.5285</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96ebd_row1_col0" class="data row1 col0" >0.8152</td>
#       <td id="T_96ebd_row1_col1" class="data row1 col1" >0.8932</td>
#       <td id="T_96ebd_row1_col2" class="data row1 col2" >0.7429</td>
#       <td id="T_96ebd_row1_col3" class="data row1 col3" >0.7647</td>
#       <td id="T_96ebd_row1_col4" class="data row1 col4" >0.7536</td>
#       <td id="T_96ebd_row1_col5" class="data row1 col5" >0.6058</td>
#       <td id="T_96ebd_row1_col6" class="data row1 col6" >0.6060</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_96ebd_row2_col0" class="data row2 col0" >0.8261</td>
#       <td id="T_96ebd_row2_col1" class="data row2 col1" >0.8702</td>
#       <td id="T_96ebd_row2_col2" class="data row2 col2" >0.7429</td>
#       <td id="T_96ebd_row2_col3" class="data row2 col3" >0.7879</td>
#       <td id="T_96ebd_row2_col4" class="data row2 col4" >0.7647</td>
#       <td id="T_96ebd_row2_col5" class="data row2 col5" >0.6270</td>
#       <td id="T_96ebd_row2_col6" class="data row2 col6" >0.6276</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_96ebd_row3_col0" class="data row3 col0" >0.8587</td>
#       <td id="T_96ebd_row3_col1" class="data row3 col1" >0.9381</td>
#       <td id="T_96ebd_row3_col2" class="data row3 col2" >0.8000</td>
#       <td id="T_96ebd_row3_col3" class="data row3 col3" >0.8235</td>
#       <td id="T_96ebd_row3_col4" class="data row3 col4" >0.8116</td>
#       <td id="T_96ebd_row3_col5" class="data row3 col5" >0.6986</td>
#       <td id="T_96ebd_row3_col6" class="data row3 col6" >0.6988</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_96ebd_row4_col0" class="data row4 col0" >0.8478</td>
#       <td id="T_96ebd_row4_col1" class="data row4 col1" >0.9108</td>
#       <td id="T_96ebd_row4_col2" class="data row4 col2" >0.8286</td>
#       <td id="T_96ebd_row4_col3" class="data row4 col3" >0.7838</td>
#       <td id="T_96ebd_row4_col4" class="data row4 col4" >0.8056</td>
#       <td id="T_96ebd_row4_col5" class="data row4 col5" >0.6807</td>
#       <td id="T_96ebd_row4_col6" class="data row4 col6" >0.6814</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_96ebd_row5_col0" class="data row5 col0" >0.8261</td>
#       <td id="T_96ebd_row5_col1" class="data row5 col1" >0.8732</td>
#       <td id="T_96ebd_row5_col2" class="data row5 col2" >0.6857</td>
#       <td id="T_96ebd_row5_col3" class="data row5 col3" >0.8276</td>
#       <td id="T_96ebd_row5_col4" class="data row5 col4" >0.7500</td>
#       <td id="T_96ebd_row5_col5" class="data row5 col5" >0.6185</td>
#       <td id="T_96ebd_row5_col6" class="data row5 col6" >0.6249</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_96ebd_row6_col0" class="data row6 col0" >0.8022</td>
#       <td id="T_96ebd_row6_col1" class="data row6 col1" >0.8561</td>
#       <td id="T_96ebd_row6_col2" class="data row6 col2" >0.6857</td>
#       <td id="T_96ebd_row6_col3" class="data row6 col3" >0.7742</td>
#       <td id="T_96ebd_row6_col4" class="data row6 col4" >0.7273</td>
#       <td id="T_96ebd_row6_col5" class="data row6 col5" >0.5730</td>
#       <td id="T_96ebd_row6_col6" class="data row6 col6" >0.5756</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_96ebd_row7_col0" class="data row7 col0" >0.7143</td>
#       <td id="T_96ebd_row7_col1" class="data row7 col1" >0.8092</td>
#       <td id="T_96ebd_row7_col2" class="data row7 col2" >0.4857</td>
#       <td id="T_96ebd_row7_col3" class="data row7 col3" >0.6800</td>
#       <td id="T_96ebd_row7_col4" class="data row7 col4" >0.5667</td>
#       <td id="T_96ebd_row7_col5" class="data row7 col5" >0.3623</td>
#       <td id="T_96ebd_row7_col6" class="data row7 col6" >0.3737</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_96ebd_row8_col0" class="data row8 col0" >0.7253</td>
#       <td id="T_96ebd_row8_col1" class="data row8 col1" >0.7837</td>
#       <td id="T_96ebd_row8_col2" class="data row8 col2" >0.6000</td>
#       <td id="T_96ebd_row8_col3" class="data row8 col3" >0.6562</td>
#       <td id="T_96ebd_row8_col4" class="data row8 col4" >0.6269</td>
#       <td id="T_96ebd_row8_col5" class="data row8 col5" >0.4102</td>
#       <td id="T_96ebd_row8_col6" class="data row8 col6" >0.4112</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_96ebd_row9_col0" class="data row9 col0" >0.7582</td>
#       <td id="T_96ebd_row9_col1" class="data row9 col1" >0.7543</td>
#       <td id="T_96ebd_row9_col2" class="data row9 col2" >0.5429</td>
#       <td id="T_96ebd_row9_col3" class="data row9 col3" >0.7600</td>
#       <td id="T_96ebd_row9_col4" class="data row9 col4" >0.6333</td>
#       <td id="T_96ebd_row9_col5" class="data row9 col5" >0.4604</td>
#       <td id="T_96ebd_row9_col6" class="data row9 col6" >0.4749</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_96ebd_row10_col0" class="data row10 col0" >0.7957</td>
#       <td id="T_96ebd_row10_col1" class="data row10 col1" >0.8508</td>
#       <td id="T_96ebd_row10_col2" class="data row10 col2" >0.6743</td>
#       <td id="T_96ebd_row10_col3" class="data row10 col3" >0.7617</td>
#       <td id="T_96ebd_row10_col4" class="data row10 col4" >0.7127</td>
#       <td id="T_96ebd_row10_col5" class="data row10 col5" >0.5559</td>
#       <td id="T_96ebd_row10_col6" class="data row10 col6" >0.5603</td>
#     </tr>
#     <tr>
#       <th id="T_96ebd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_96ebd_row11_col0" class="data row11 col0" >0.0470</td>
#       <td id="T_96ebd_row11_col1" class="data row11 col1" >0.0552</td>
#       <td id="T_96ebd_row11_col2" class="data row11 col2" >0.1047</td>
#       <td id="T_96ebd_row11_col3" class="data row11 col3" >0.0523</td>
#       <td id="T_96ebd_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
#
#
# ------
#
#
# Resumen del modelo
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=42, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)
#
#
# ------
#
#
# Predicciones en el conjunto/set de test
# <style type="text/css">
# </style>
# <table id="T_90c41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90c41_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_90c41_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_90c41_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_90c41_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_90c41_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_90c41_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_90c41_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_90c41_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90c41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90c41_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_90c41_row0_col1" class="data row0 col1" >0.7990</td>
#       <td id="T_90c41_row0_col2" class="data row0 col2" >0.8578</td>
#       <td id="T_90c41_row0_col3" class="data row0 col3" >0.7400</td>
#       <td id="T_90c41_row0_col4" class="data row0 col4" >0.7351</td>
#       <td id="T_90c41_row0_col5" class="data row0 col5" >0.7375</td>
#       <td id="T_90c41_row0_col6" class="data row0 col6" >0.5747</td>
#       <td id="T_90c41_row0_col7" class="data row0 col7" >0.5747</td>
#     </tr>
#   </tbody>
# </table>
# ------
#
#
#       pclass     sex   age  sibsp  parch       fare embarked  survived  \
# 1289       3    male  21.0      1      0   6.495800        S     False
# 352        2  female  40.0      1      1  39.000000        S      True
# 1189       3  female   4.0      1      1  16.700001        S      True
# 78         1  female  64.0      0      2  83.158302        C      True
# 974        3    male  30.0      1      0  16.100000        S     False
#
#       prediction_label  prediction_score
# 1289                 0            0.8640
# 352                  1            0.9968
# 1189                 1            0.7978
# 78                   1            0.9938
# 974                  0            0.9308

# %%
print(gbc_tuned.get_params())
# Out:
# {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'num_leaves': 31, 'objective': None, 'random_state': 42, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 1.0, 'subsample_for_bin': 200000, 'subsample_freq': 0}

# %%
np.random.seed(57)


n_samples = 50

df_synthtic_test = pd.DataFrame({
    'pclass': np.random.choice([1, 2, 3], size=n_samples),
    'sex': np.random.choice(['male', 'female'], size=n_samples),
    'age': np.random.uniform(0, 80, size=n_samples),
    'sibsp': np.random.randint(0, 10, size=n_samples),
    'parch': np.random.randint(0, 4, size=n_samples),
    'fare': np.random.uniform(10, 2000, size=n_samples),
    'embarked': np.random.choice(['C', 'Q', 'S'], size=n_samples)
})

df_synthtic_test.head()
# Out:
#    pclass   sex        age  sibsp  parch         fare embarked
# 0       3  male  29.549676      6      0  1535.239303        Q
# 1       2  male  22.782733      6      2   913.722493        C
# 2       3  male  74.169372      3      3   277.143499        C
# 3       1  male  62.041734      4      0   527.476471        Q
# 4       3  male  51.305236      2      1   717.351105        S

# %%
prediccines_sinteticas = predict_model(gbc_tuned, data=df_synthtic_test)

prediccines_sinteticas.head()
# Out:
#    pclass   sex        age  sibsp  parch         fare embarked  \
# 0       3  male  29.549675      6      0  1535.239258        Q
# 1       2  male  22.782732      6      2   913.722473        C
# 2       3  male  74.169373      3      3   277.143494        C
# 3       1  male  62.041733      4      0   527.476501        Q
# 4       3  male  51.305237      2      1   717.351074        S
#
#    prediction_label  prediction_score
# 0                 0            0.9823
# 1                 0            0.9756
# 2                 0            0.9869
# 3                 0            0.9802
# 4                 0            0.9744

# %% [markdown]
# # Guardar el modelo

# %%
from pycaret.classification import save_model

# %%
MODELS_DIR = Path.cwd().resolve().parent / "modelos"
MODELS_DIR.mkdir(exist_ok=True)

model_path = MODELS_DIR / "lightgbm_tuned_model"

save_model(gbc_tuned, model_path)
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['age', 'fare', 'sibsp', 'parch'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None, include=['sex', 'embark...
#                   LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, importance_type='split',
#                                  learning_rate=0.1, max_depth=-1,
#                                  min_child_samples=20, min_child_weight=0.001,
#                                  min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                  num_leaves=31, objective=None, random_state=42,
#                                  reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  '/Users/david.palacio/Documents/academia/titanic-prediccion/modelos/lightgbm_tuned_model.pkl')
